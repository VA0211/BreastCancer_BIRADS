# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
results = pd.read_csv('./output/best/prediction_result.csv')
incorrect_predictions = results[results['true_class'] != results['predicted_class']]
incorrect_predictions
# Out:
#                                                img_path  true_class  \
# 2     E:/vindr_mammo/Data/png/1fe77db1e47d9133c2bc79...           0
# 12    E:/vindr_mammo/Data/png/00dfcde5aaf6cd0aab3c3a...           0
# 20    E:/vindr_mammo/Data/png/3b9d3e9aa2fcdefd74d4cb...           0
# 21    E:/vindr_mammo/Data/png/afa8d58b60cf82ce642d5c...           0
# 23    E:/vindr_mammo/Data/png/523082bc2eed932d4ba662...           0
# ...                                                 ...         ...
# 1988  E:/vindr_mammo/Data/png/4bc4424e8d12c1c7d4560e...           0
# 1989  E:/vindr_mammo/Data/png/3f14fe08772a5b823f2888...           0
# 1992  E:/vindr_mammo/Data/png/4bd6ad56e19c08d4f4ce85...           0
# 1993  E:/vindr_mammo/Data/png/b719ac3962da832e55f14d...           0
# 1997  E:/vindr_mammo/Data/png/fbc135926b71e4f85482ba...           0
#
#       predicted_class  prob_class_0  prob_class_1
# 2                   1      0.432204      0.567796
# 12                  1      0.447730      0.552270
# 20                  1      0.464031      0.535969
# 21                  1      0.461737      0.538263
# 23                  1      0.450270      0.549729
# ...               ...           ...           ...
# 1988                1      0.282392      0.717608
# 1989                1      0.454984      0.545016
# 1992                1      0.387699      0.612302
# 1993                1      0.466180      0.533820
# 1997                1      0.490424      0.509576
#
# [766 rows x 5 columns]

# %%
value = incorrect_predictions['true_class'].value_counts()
plt.figure(figsize=(8, 6))
plt.title('Breast Cancer Finding - Wrongly Predicted Label', fontsize=14)
plt.pie(value, labels=value.index, autopct='%1.1f%%')
plt.show()
