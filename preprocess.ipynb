# %%
import pandas as pd
df = pd.read_csv('./Data/breast-level_annotations.csv')
print(df['breast_density'].value_counts(normalize=True).to_frame())
print(df['breast_birads'].value_counts(normalize=True).to_frame())
print(df['view_position'].value_counts(normalize=True).to_frame())
print(df['laterality'].value_counts(normalize=True).to_frame())
# Out:
#                 proportion
# breast_density
# DENSITY C           0.7646
# DENSITY D           0.1350
# DENSITY B           0.0954
# DENSITY A           0.0050
#                proportion
# breast_birads
# BI-RADS 1          0.6703
# BI-RADS 2          0.2338
# BI-RADS 3          0.0465
# BI-RADS 4          0.0381
# BI-RADS 5          0.0113
#                proportion
# view_position
# CC                0.50005
# MLO               0.49995
#             proportion
# laterality
# L                  0.5
# R                  0.5

# %%
df = pd.read_csv('./Data/full_df.csv')
print(df['breast_density'].value_counts(normalize=True).to_frame())
print(df['breast_birads'].value_counts(normalize=True).to_frame())
print(df['view_position'].value_counts(normalize=True).to_frame())
print(df['laterality'].value_counts(normalize=True).to_frame())
# Out:
#                 proportion
# breast_density
# DENSITY C         0.764434
# DENSITY D         0.135091
# DENSITY B         0.095476
# DENSITY A         0.004999
#                proportion
# breast_birads
# BI-RADS 1        0.670082
# BI-RADS 2        0.233692
# BI-RADS 3        0.046613
# BI-RADS 4        0.038240
# BI-RADS 5        0.011372
#                proportion
# view_position
# CC               0.500062
# MLO              0.499938
#             proportion
# laterality
# L                  0.5
# R                  0.5

# %%
from modules import visualization
dicom_path = 'E:/vindr_mammo/Data/images/0a0c5108270e814818c1ad002482ce74/0a6a90bdc088e0cc62df8d2d58d14840.dicom'
visualization.demo(dicom_path)

# %%
from modules import preprocess
import pandas as pd
import os
import matplotlib.pyplot as plt

data_dir = 'E:/vindr_mammo/Data/'
out_path = 'E:/vindr_mammo/Data/png'
df = pd.read_csv('./Data/full_df.csv').head(1)
dicom_path = os.path.join(data_dir, 'images', df['study_id'][0], df['image_id'][0] + '.dicom')
img = preprocess.fit_image(dicom_path)
plt.imshow(img, cmap="gray")
plt.show()

# %%
import pandas as pd
import os

out_path = 'E:/vindr_mammo/Data/png'
df = pd.read_csv('./Data/full_df.csv')
count = 0
missing = []
for idx, row in df.iterrows():
    out_folder = os.path.join(out_path, row['study_id'])

    save_path = os.path.join(out_path,row['study_id'], row['image_id'] + '.png')
    if os.path.isfile(save_path):
        count += 1
    else:
        missing.append([row['study_id'], row['image_id']])
if count == len(df):
    print("OKKK")
# Out:
# OKKK

# %% [markdown]
# ---

# %% [markdown]
# **Note**: <br>
# The above was to test if the fuction work <br>
# The following is to preprocess all the img <br>
# The full_df (75% of the original) is split using the code split_data.py in modules folder

# %%
from modules import preprocess
import pandas as pd

data_dir = 'E:/vindr_mammo/Data/'
out_path = 'E:/vindr_mammo/Data/png'
df = pd.read_csv('./Data/full_df.csv')
preprocess.main(df, data_dir, out_path)
